# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
word_pairs = [
    ("car", "automobile"),
    ("happy", "joyful"),
    ("big", "large"),
    ("fast", "quick"),
    ("teacher", "educator")
]
def get_cosine_similarity(word1, word2):
    vectorizer = TfidfVectorizer()
    vectors = vectorizer.fit_transform([word1, word2])
    similarity = cosine_similarity(vectors[0], vectors[1])
    return similarity[0][0]
for w1, w2 in word_pairs:
    sim = get_cosine_similarity(w1, w2)
    print(f"{w1} - {w2} -> Similarity: {sim:.2f}")
# Out:
# car - automobile -> Similarity: 0.00
# happy - joyful -> Similarity: 0.00
# big - large -> Similarity: 0.00
# fast - quick -> Similarity: 0.00
# teacher - educator -> Similarity: 0.00
